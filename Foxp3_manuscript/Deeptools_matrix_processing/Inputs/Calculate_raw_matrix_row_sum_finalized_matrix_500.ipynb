# %%
import pandas as pd 
import numpy as np

# %%
def Onestep(matrix_name):
    specific_rows = [0,1]
    df=pd.read_csv(matrix_name, sep='\t', skiprows = lambda x: x in specific_rows)
    dfA=df.fillna(0).astype(float).mean(axis=1).to_frame().rename(columns={0: matrix_name}).reset_index().drop(['index'], axis=1)
    return dfA

# %%
ATAC_pre_tTreg_TnGpeak = Onestep('ATAC_pre_tTreg.bw_TnGpeak_matrix')
ATAC_Treg_TnGpeak = Onestep('ATAC_Treg.bw_TnGpeak_matrix')
ATAC_tTreg_TnGpeak = Onestep('ATAC_tTreg.bw_TnGpeak_matrix')
Chips_TnGpeak = Onestep('Chips.bw_TnGpeak_matrix')
Cutruns_TnGpeak = Onestep('Cutruns.bw_TnGpeak_matrix')
Foxp3_Chipseq_Treg_TnGpeak = Onestep('Foxp3_Chipseq_Treg.bw_TnGpeak_matrix')
H3K27ac_Cd4CreSatb1CKO_pre_tTreg_TnGpeak = Onestep('H3K27ac_Cd4CreSatb1CKO_pre_tTreg.bw_TnGpeak_matrix')
H3K27ac_pre_tTreg_TnGpeak = Onestep('H3K27ac_pre_tTreg.bw_TnGpeak_matrix')
H3K27ac_Treg_TnGpeak = Onestep('H3K27ac_Treg.bw_TnGpeak_matrix')
H3K27ac_tTreg_TnGpeak = Onestep('H3K27ac_tTreg.bw_TnGpeak_matrix')
H3K27me3_pre_tTreg_TnGpeak = Onestep('H3K27me3_pre_tTreg.bw_TnGpeak_matrix')
H3K27me3_Treg_TnGpeak = Onestep('H3K27me3_Treg.bw_TnGpeak_matrix')
H3K27me3_tTreg_TnGpeak = Onestep('H3K27me3_tTreg.bw_TnGpeak_matrix')
H3K4me1_pre_tTreg_TnGpeak = Onestep('H3K4me1_pre_tTreg.bw_TnGpeak_matrix')
H3K4me1_Treg_TnGpeak = Onestep('H3K4me1_Treg.bw_TnGpeak_matrix')
H3K4me1_tTreg_TnGpeak = Onestep('H3K4me1_tTreg.bw_TnGpeak_matrix')
H3K4me3_pre_tTreg_TnGpeak = Onestep('H3K4me3_pre_tTreg.bw_TnGpeak_matrix')
H3K4me3_Treg_TnGpeak = Onestep('H3K4me3_Treg.bw_TnGpeak_matrix')
H3K4me3_tTreg_TnGpeak = Onestep('H3K4me3_tTreg.bw_TnGpeak_matrix')
MBD_pre_tTreg_TnGpeak = Onestep('MBD_pre_tTreg.bw_TnGpeak_matrix')
MBD_Treg_TnGpeak = Onestep('MBD_Treg.bw_TnGpeak_matrix')
MBD_tTreg_TnGpeak = Onestep('MBD_tTreg.bw_TnGpeak_matrix')
Fp3_act_TnGpeak = Onestep('Fp3_act.bw_TnGpeak_matrix')
Fp3_res_TnGpeak = Onestep('Fp3_res.bw_TnGpeak_matrix')
Kik_act_TnGpeak = Onestep('Kik_act.bw_TnGpeak_matrix')
Kik_res_TnGpeak = Onestep('Kik_res.bw_TnGpeak_matrix')

ATAC_pre_tTreg_nonTnGpeak = Onestep('ATAC_pre_tTreg.bw_nonTnGpeak_matrix')
ATAC_Treg_nonTnGpeak = Onestep('ATAC_Treg.bw_nonTnGpeak_matrix')
ATAC_tTreg_nonTnGpeak = Onestep('ATAC_tTreg.bw_nonTnGpeak_matrix')
Chips_nonTnGpeak = Onestep('Chips.bw_nonTnGpeak_matrix')
Cutruns_nonTnGpeak = Onestep('Cutruns.bw_nonTnGpeak_matrix')
Foxp3_Chipseq_Treg_nonTnGpeak = Onestep('Foxp3_Chipseq_Treg.bw_nonTnGpeak_matrix')
H3K27ac_Cd4CreSatb1CKO_pre_tTreg_nonTnGpeak = Onestep('H3K27ac_Cd4CreSatb1CKO_pre_tTreg.bw_nonTnGpeak_matrix')
H3K27ac_pre_tTreg_nonTnGpeak = Onestep('H3K27ac_pre_tTreg.bw_nonTnGpeak_matrix')
H3K27ac_Treg_nonTnGpeak = Onestep('H3K27ac_Treg.bw_nonTnGpeak_matrix')
H3K27ac_tTreg_nonTnGpeak = Onestep('H3K27ac_tTreg.bw_nonTnGpeak_matrix')
H3K27me3_pre_tTreg_nonTnGpeak = Onestep('H3K27me3_pre_tTreg.bw_nonTnGpeak_matrix')
H3K27me3_Treg_nonTnGpeak = Onestep('H3K27me3_Treg.bw_nonTnGpeak_matrix')
H3K27me3_tTreg_nonTnGpeak = Onestep('H3K27me3_tTreg.bw_nonTnGpeak_matrix')
H3K4me1_pre_tTreg_nonTnGpeak = Onestep('H3K4me1_pre_tTreg.bw_nonTnGpeak_matrix')
H3K4me1_Treg_nonTnGpeak = Onestep('H3K4me1_Treg.bw_nonTnGpeak_matrix')
H3K4me1_tTreg_nonTnGpeak = Onestep('H3K4me1_tTreg.bw_nonTnGpeak_matrix')
H3K4me3_pre_tTreg_nonTnGpeak = Onestep('H3K4me3_pre_tTreg.bw_nonTnGpeak_matrix')
H3K4me3_Treg_nonTnGpeak = Onestep('H3K4me3_Treg.bw_nonTnGpeak_matrix')
H3K4me3_tTreg_nonTnGpeak = Onestep('H3K4me3_tTreg.bw_nonTnGpeak_matrix')
MBD_pre_tTreg_nonTnGpeak = Onestep('MBD_pre_tTreg.bw_nonTnGpeak_matrix')
MBD_Treg_nonTnGpeak = Onestep('MBD_Treg.bw_nonTnGpeak_matrix')
MBD_tTreg_nonTnGpeak = Onestep('MBD_tTreg.bw_nonTnGpeak_matrix')
Fp3_act_nonTnGpeak = Onestep('Fp3_act.bw_nonTnGpeak_matrix')
Fp3_res_nonTnGpeak = Onestep('Fp3_res.bw_nonTnGpeak_matrix')
Kik_act_nonTnGpeak = Onestep('Kik_act.bw_nonTnGpeak_matrix')
Kik_res_nonTnGpeak = Onestep('Kik_res.bw_nonTnGpeak_matrix')

ATAC_pre_tTreg_nonTnGpeak2 = Onestep('ATAC_pre_tTreg.bw_nonTnGpeak2_matrix')
ATAC_Treg_nonTnGpeak2 = Onestep('ATAC_Treg.bw_nonTnGpeak2_matrix')
ATAC_tTreg_nonTnGpeak2 = Onestep('ATAC_tTreg.bw_nonTnGpeak2_matrix')
Chips_nonTnGpeak2 = Onestep('Chips.bw_nonTnGpeak2_matrix')
Cutruns_nonTnGpeak2 = Onestep('Cutruns.bw_nonTnGpeak2_matrix')
Foxp3_Chipseq_Treg_nonTnGpeak2 = Onestep('Foxp3_Chipseq_Treg.bw_nonTnGpeak2_matrix')
H3K27ac_Cd4CreSatb1CKO_pre_tTreg_nonTnGpeak2 = Onestep('H3K27ac_Cd4CreSatb1CKO_pre_tTreg.bw_nonTnGpeak2_matrix')
H3K27ac_pre_tTreg_nonTnGpeak2 = Onestep('H3K27ac_pre_tTreg.bw_nonTnGpeak2_matrix')
H3K27ac_Treg_nonTnGpeak2 = Onestep('H3K27ac_Treg.bw_nonTnGpeak2_matrix')
H3K27ac_tTreg_nonTnGpeak2 = Onestep('H3K27ac_tTreg.bw_nonTnGpeak2_matrix')
H3K27me3_pre_tTreg_nonTnGpeak2 = Onestep('H3K27me3_pre_tTreg.bw_nonTnGpeak2_matrix')
H3K27me3_Treg_nonTnGpeak2 = Onestep('H3K27me3_Treg.bw_nonTnGpeak2_matrix')
H3K27me3_tTreg_nonTnGpeak2 = Onestep('H3K27me3_tTreg.bw_nonTnGpeak2_matrix')
H3K4me1_pre_tTreg_nonTnGpeak2 = Onestep('H3K4me1_pre_tTreg.bw_nonTnGpeak2_matrix')
H3K4me1_Treg_nonTnGpeak2 = Onestep('H3K4me1_Treg.bw_nonTnGpeak2_matrix')
H3K4me1_tTreg_nonTnGpeak2 = Onestep('H3K4me1_tTreg.bw_nonTnGpeak2_matrix')
H3K4me3_pre_tTreg_nonTnGpeak2 = Onestep('H3K4me3_pre_tTreg.bw_nonTnGpeak2_matrix')
H3K4me3_Treg_nonTnGpeak2 = Onestep('H3K4me3_Treg.bw_nonTnGpeak2_matrix')
H3K4me3_tTreg_nonTnGpeak2 = Onestep('H3K4me3_tTreg.bw_nonTnGpeak2_matrix')
MBD_pre_tTreg_nonTnGpeak2 = Onestep('MBD_pre_tTreg.bw_nonTnGpeak2_matrix')
MBD_Treg_nonTnGpeak2 = Onestep('MBD_Treg.bw_nonTnGpeak2_matrix')
MBD_tTreg_nonTnGpeak2 = Onestep('MBD_tTreg.bw_nonTnGpeak2_matrix')
Fp3_act_nonTnGpeak2 = Onestep('Fp3_act.bw_nonTnGpeak2_matrix')
Fp3_res_nonTnGpeak2 = Onestep('Fp3_res.bw_nonTnGpeak2_matrix')
Kik_act_nonTnGpeak2 = Onestep('Kik_act.bw_nonTnGpeak2_matrix')
Kik_res_nonTnGpeak2 = Onestep('Kik_res.bw_nonTnGpeak2_matrix')

ATAC_pre_tTreg_TnGpeak2 = Onestep('ATAC_pre_tTreg.bw_TnGpeak2_matrix')
ATAC_Treg_TnGpeak2 = Onestep('ATAC_Treg.bw_TnGpeak2_matrix')
ATAC_tTreg_TnGpeak2 = Onestep('ATAC_tTreg.bw_TnGpeak2_matrix')
Chips_TnGpeak2 = Onestep('Chips.bw_TnGpeak2_matrix')
Cutruns_TnGpeak2 = Onestep('Cutruns.bw_TnGpeak2_matrix')
Foxp3_Chipseq_Treg_TnGpeak2 = Onestep('Foxp3_Chipseq_Treg.bw_TnGpeak2_matrix')
H3K27ac_Cd4CreSatb1CKO_pre_tTreg_TnGpeak2 = Onestep('H3K27ac_Cd4CreSatb1CKO_pre_tTreg.bw_TnGpeak2_matrix')
H3K27ac_pre_tTreg_TnGpeak2 = Onestep('H3K27ac_pre_tTreg.bw_TnGpeak2_matrix')
H3K27ac_Treg_TnGpeak2 = Onestep('H3K27ac_Treg.bw_TnGpeak2_matrix')
H3K27ac_tTreg_TnGpeak2 = Onestep('H3K27ac_tTreg.bw_TnGpeak2_matrix')
H3K27me3_pre_tTreg_TnGpeak2 = Onestep('H3K27me3_pre_tTreg.bw_TnGpeak2_matrix')
H3K27me3_Treg_TnGpeak2 = Onestep('H3K27me3_Treg.bw_TnGpeak2_matrix')
H3K27me3_tTreg_TnGpeak2 = Onestep('H3K27me3_tTreg.bw_TnGpeak2_matrix')
H3K4me1_pre_tTreg_TnGpeak2 = Onestep('H3K4me1_pre_tTreg.bw_TnGpeak2_matrix')
H3K4me1_Treg_TnGpeak2 = Onestep('H3K4me1_Treg.bw_TnGpeak2_matrix')
H3K4me1_tTreg_TnGpeak2 = Onestep('H3K4me1_tTreg.bw_TnGpeak2_matrix')
H3K4me3_pre_tTreg_TnGpeak2 = Onestep('H3K4me3_pre_tTreg.bw_TnGpeak2_matrix')
H3K4me3_Treg_TnGpeak2 = Onestep('H3K4me3_Treg.bw_TnGpeak2_matrix')
H3K4me3_tTreg_TnGpeak2 = Onestep('H3K4me3_tTreg.bw_TnGpeak2_matrix')
MBD_pre_tTreg_TnGpeak2 = Onestep('MBD_pre_tTreg.bw_TnGpeak2_matrix')
MBD_Treg_TnGpeak2 = Onestep('MBD_Treg.bw_TnGpeak2_matrix')
MBD_tTreg_TnGpeak2 = Onestep('MBD_tTreg.bw_TnGpeak2_matrix')
Fp3_act_TnGpeak2 = Onestep('Fp3_act.bw_TnGpeak2_matrix')
Fp3_res_TnGpeak2 = Onestep('Fp3_res.bw_TnGpeak2_matrix')
Kik_act_TnGpeak2 = Onestep('Kik_act.bw_TnGpeak2_matrix')
Kik_res_TnGpeak2 = Onestep('Kik_res.bw_TnGpeak2_matrix')

# %%
ATAC_pre_tTreg_TnG500 = Onestep('ATAC_pre_tTreg.bw_TnG500_matrix')
ATAC_Treg_TnG500 = Onestep('ATAC_Treg.bw_TnG500_matrix')
ATAC_tTreg_TnG500 = Onestep('ATAC_tTreg.bw_TnG500_matrix')
Chips_TnG500 = Onestep('Chips.bw_TnG500_matrix')
Cutruns_TnG500 = Onestep('Cutruns.bw_TnG500_matrix')
Foxp3_Chipseq_Treg_TnG500 = Onestep('Foxp3_Chipseq_Treg.bw_TnG500_matrix')
H3K27ac_Cd4CreSatb1CKO_pre_tTreg_TnG500 = Onestep('H3K27ac_Cd4CreSatb1CKO_pre_tTreg.bw_TnG500_matrix')
H3K27ac_pre_tTreg_TnG500 = Onestep('H3K27ac_pre_tTreg.bw_TnG500_matrix')
H3K27ac_Treg_TnG500 = Onestep('H3K27ac_Treg.bw_TnG500_matrix')
H3K27ac_tTreg_TnG500 = Onestep('H3K27ac_tTreg.bw_TnG500_matrix')
H3K27me3_pre_tTreg_TnG500 = Onestep('H3K27me3_pre_tTreg.bw_TnG500_matrix')
H3K27me3_Treg_TnG500 = Onestep('H3K27me3_Treg.bw_TnG500_matrix')
H3K27me3_tTreg_TnG500 = Onestep('H3K27me3_tTreg.bw_TnG500_matrix')
H3K4me1_pre_tTreg_TnG500 = Onestep('H3K4me1_pre_tTreg.bw_TnG500_matrix')
H3K4me1_Treg_TnG500 = Onestep('H3K4me1_Treg.bw_TnG500_matrix')
H3K4me1_tTreg_TnG500 = Onestep('H3K4me1_tTreg.bw_TnG500_matrix')
H3K4me3_pre_tTreg_TnG500 = Onestep('H3K4me3_pre_tTreg.bw_TnG500_matrix')
H3K4me3_Treg_TnG500 = Onestep('H3K4me3_Treg.bw_TnG500_matrix')
H3K4me3_tTreg_TnG500 = Onestep('H3K4me3_tTreg.bw_TnG500_matrix')
MBD_pre_tTreg_TnG500 = Onestep('MBD_pre_tTreg.bw_TnG500_matrix')
MBD_Treg_TnG500 = Onestep('MBD_Treg.bw_TnG500_matrix')
MBD_tTreg_TnG500 = Onestep('MBD_tTreg.bw_TnG500_matrix')
Fp3_act_TnG500 = Onestep('Fp3_act.bw_TnG500_matrix')
Fp3_res_TnG500 = Onestep('Fp3_res.bw_TnG500_matrix')
Kik_act_TnG500 = Onestep('Kik_act.bw_TnG500_matrix')
Kik_res_TnG500 = Onestep('Kik_res.bw_TnG500_matrix')
FPD_TnG500 = Onestep('FPD.bw_TnG500_matrix')
SMC1a_TnG500 = Onestep('SMC1a.bw_TnG500_matrix')
SMC1a_TnG500_refined = Onestep('CC_TnG_SMC1a500_refined_matrix')

ATAC_pre_tTreg_nonTnG500 = Onestep('ATAC_pre_tTreg.bw_nonTnG500_matrix')
ATAC_Treg_nonTnG500 = Onestep('ATAC_Treg.bw_nonTnG500_matrix')
ATAC_tTreg_nonTnG500 = Onestep('ATAC_tTreg.bw_nonTnG500_matrix')
Chips_nonTnG500 = Onestep('Chips.bw_nonTnG500_matrix')
Cutruns_nonTnG500 = Onestep('Cutruns.bw_nonTnG500_matrix')
Foxp3_Chipseq_Treg_nonTnG500 = Onestep('Foxp3_Chipseq_Treg.bw_nonTnG500_matrix')
H3K27ac_Cd4CreSatb1CKO_pre_tTreg_nonTnG500 = Onestep('H3K27ac_Cd4CreSatb1CKO_pre_tTreg.bw_nonTnG500_matrix')
H3K27ac_pre_tTreg_nonTnG500 = Onestep('H3K27ac_pre_tTreg.bw_nonTnG500_matrix')
H3K27ac_Treg_nonTnG500 = Onestep('H3K27ac_Treg.bw_nonTnG500_matrix')
H3K27ac_tTreg_nonTnG500 = Onestep('H3K27ac_tTreg.bw_nonTnG500_matrix')
H3K27me3_pre_tTreg_nonTnG500 = Onestep('H3K27me3_pre_tTreg.bw_nonTnG500_matrix')
H3K27me3_Treg_nonTnG500 = Onestep('H3K27me3_Treg.bw_nonTnG500_matrix')
H3K27me3_tTreg_nonTnG500 = Onestep('H3K27me3_tTreg.bw_nonTnG500_matrix')
H3K4me1_pre_tTreg_nonTnG500 = Onestep('H3K4me1_pre_tTreg.bw_nonTnG500_matrix')
H3K4me1_Treg_nonTnG500 = Onestep('H3K4me1_Treg.bw_nonTnG500_matrix')
H3K4me1_tTreg_nonTnG500 = Onestep('H3K4me1_tTreg.bw_nonTnG500_matrix')
H3K4me3_pre_tTreg_nonTnG500 = Onestep('H3K4me3_pre_tTreg.bw_nonTnG500_matrix')
H3K4me3_Treg_nonTnG500 = Onestep('H3K4me3_Treg.bw_nonTnG500_matrix')
H3K4me3_tTreg_nonTnG500 = Onestep('H3K4me3_tTreg.bw_nonTnG500_matrix')
MBD_pre_tTreg_nonTnG500 = Onestep('MBD_pre_tTreg.bw_nonTnG500_matrix')
MBD_Treg_nonTnG500 = Onestep('MBD_Treg.bw_nonTnG500_matrix')
MBD_tTreg_nonTnG500 = Onestep('MBD_tTreg.bw_nonTnG500_matrix')
Fp3_act_nonTnG500 = Onestep('Fp3_act.bw_nonTnG500_matrix')
Fp3_res_nonTnG500 = Onestep('Fp3_res.bw_nonTnG500_matrix')
Kik_act_nonTnG500 = Onestep('Kik_act.bw_nonTnG500_matrix')
Kik_res_nonTnG500 = Onestep('Kik_res.bw_nonTnG500_matrix')
FPD_nonTnG500 = Onestep('FPD.bw_nonTnG500_matrix')
SMC1a_nonTnG500 = Onestep('SMC1a.bw_nonTnG500_matrix')
SMC1a_nonTnG500_refined = Onestep('CC_nonTnG_SMC1a500_refined_matrix')

# %%
TnG_peak=pd.concat([ATAC_pre_tTreg_TnGpeak , ATAC_Treg_TnGpeak , ATAC_tTreg_TnGpeak , Chips_TnGpeak , Cutruns_TnGpeak , Foxp3_Chipseq_Treg_TnGpeak , H3K27ac_Cd4CreSatb1CKO_pre_tTreg_TnGpeak , H3K27ac_pre_tTreg_TnGpeak , H3K27ac_Treg_TnGpeak , H3K27ac_tTreg_TnGpeak , H3K27me3_pre_tTreg_TnGpeak , H3K27me3_Treg_TnGpeak , H3K27me3_tTreg_TnGpeak , H3K4me1_pre_tTreg_TnGpeak , H3K4me1_Treg_TnGpeak , H3K4me1_tTreg_TnGpeak , H3K4me3_pre_tTreg_TnGpeak , H3K4me3_Treg_TnGpeak , H3K4me3_tTreg_TnGpeak , MBD_pre_tTreg_TnGpeak , MBD_Treg_TnGpeak , MBD_tTreg_TnGpeak , Fp3_act_TnGpeak , Fp3_res_TnGpeak , Kik_act_TnGpeak , Kik_res_TnGpeak, FPD_TnGpeak, SMC1a_TnGpeak], axis=1)
#TnG_peak2=pd.concat([ATAC_pre_tTreg_TnGpeak2 , ATAC_Treg_TnGpeak2 , ATAC_tTreg_TnGpeak2 , Chips_TnGpeak2 , Cutruns_TnGpeak2 , Foxp3_Chipseq_Treg_TnGpeak2 , H3K27ac_Cd4CreSatb1CKO_pre_tTreg_TnGpeak2 , H3K27ac_pre_tTreg_TnGpeak2 , H3K27ac_Treg_TnGpeak2 , H3K27ac_tTreg_TnGpeak2 , H3K27me3_pre_tTreg_TnGpeak2 , H3K27me3_Treg_TnGpeak2 , H3K27me3_tTreg_TnGpeak2 , H3K4me1_pre_tTreg_TnGpeak2 , H3K4me1_Treg_TnGpeak2 , H3K4me1_tTreg_TnGpeak2 , H3K4me3_pre_tTreg_TnGpeak2 , H3K4me3_Treg_TnGpeak2 , H3K4me3_tTreg_TnGpeak2 , MBD_pre_tTreg_TnGpeak2 , MBD_Treg_TnGpeak2 , MBD_tTreg_TnGpeak2 , Fp3_act_TnGpeak2 , Fp3_res_TnGpeak2 , Kik_act_TnGpeak2 , Kik_res_TnGpeak2], axis=1)
nonTnG_peak=pd.concat([ATAC_pre_tTreg_nonTnGpeak , ATAC_Treg_nonTnGpeak , ATAC_tTreg_nonTnGpeak , Chips_nonTnGpeak , Cutruns_nonTnGpeak , Foxp3_Chipseq_Treg_nonTnGpeak , H3K27ac_Cd4CreSatb1CKO_pre_tTreg_nonTnGpeak , H3K27ac_pre_tTreg_nonTnGpeak , H3K27ac_Treg_nonTnGpeak , H3K27ac_tTreg_nonTnGpeak , H3K27me3_pre_tTreg_nonTnGpeak , H3K27me3_Treg_nonTnGpeak , H3K27me3_tTreg_nonTnGpeak , H3K4me1_pre_tTreg_nonTnGpeak , H3K4me1_Treg_nonTnGpeak , H3K4me1_tTreg_nonTnGpeak , H3K4me3_pre_tTreg_nonTnGpeak , H3K4me3_Treg_nonTnGpeak , H3K4me3_tTreg_nonTnGpeak , MBD_pre_tTreg_nonTnGpeak , MBD_Treg_nonTnGpeak , MBD_tTreg_nonTnGpeak , Fp3_act_nonTnGpeak , Fp3_res_nonTnGpeak , Kik_act_nonTnGpeak , Kik_res_nonTnGpeak, FPD_nonTnGpeak, SMC1a_nonTnGpeak], axis=1)
#nonTnG_peak2=pd.concat([ATAC_pre_tTreg_nonTnGpeak2 , ATAC_Treg_nonTnGpeak2 , ATAC_tTreg_nonTnGpeak2 , Chips_nonTnGpeak2 , Cutruns_nonTnGpeak2 , Foxp3_Chipseq_Treg_nonTnGpeak2 , H3K27ac_Cd4CreSatb1CKO_pre_tTreg_nonTnGpeak2 , H3K27ac_pre_tTreg_nonTnGpeak2 , H3K27ac_Treg_nonTnGpeak2 , H3K27ac_tTreg_nonTnGpeak2 , H3K27me3_pre_tTreg_nonTnGpeak2 , H3K27me3_Treg_nonTnGpeak2 , H3K27me3_tTreg_nonTnGpeak2 , H3K4me1_pre_tTreg_nonTnGpeak2 , H3K4me1_Treg_nonTnGpeak2 , H3K4me1_tTreg_nonTnGpeak2 , H3K4me3_pre_tTreg_nonTnGpeak2 , H3K4me3_Treg_nonTnGpeak2 , H3K4me3_tTreg_nonTnGpeak2 , MBD_pre_tTreg_nonTnGpeak2 , MBD_Treg_nonTnGpeak2 , MBD_tTreg_nonTnGpeak2 , Fp3_act_nonTnGpeak2 , Fp3_res_nonTnGpeak2 , Kik_act_nonTnGpeak2 , Kik_res_nonTnGpeak2], axis=1)

# %%
TnG_peak=pd.concat([ATAC_pre_tTreg_TnG500 , ATAC_Treg_TnG500 , ATAC_tTreg_TnG500 , Chips_TnG500 , Cutruns_TnG500 , Foxp3_Chipseq_Treg_TnG500 , H3K27ac_Cd4CreSatb1CKO_pre_tTreg_TnG500 , H3K27ac_pre_tTreg_TnG500 , H3K27ac_Treg_TnG500 , H3K27ac_tTreg_TnG500 , H3K27me3_pre_tTreg_TnG500 , H3K27me3_Treg_TnG500 , H3K27me3_tTreg_TnG500 , H3K4me1_pre_tTreg_TnG500 , H3K4me1_Treg_TnG500 , H3K4me1_tTreg_TnG500 , H3K4me3_pre_tTreg_TnG500 , H3K4me3_Treg_TnG500 , H3K4me3_tTreg_TnG500 , MBD_pre_tTreg_TnG500 , MBD_Treg_TnG500 , MBD_tTreg_TnG500 , Fp3_act_TnG500 , Fp3_res_TnG500 , Kik_act_TnG500 , Kik_res_TnG500, FPD_TnG500, SMC1a_TnG500, SMC1a_TnG500_refined], axis=1)
#TnG_peak2=pd.concat([ATAC_pre_tTreg_TnG5002 , ATAC_Treg_TnG5002 , ATAC_tTreg_TnG5002 , Chips_TnG5002 , Cutruns_TnG5002 , Foxp3_Chipseq_Treg_TnG5002 , H3K27ac_Cd4CreSatb1CKO_pre_tTreg_TnG5002 , H3K27ac_pre_tTreg_TnG5002 , H3K27ac_Treg_TnG5002 , H3K27ac_tTreg_TnG5002 , H3K27me3_pre_tTreg_TnG5002 , H3K27me3_Treg_TnG5002 , H3K27me3_tTreg_TnG5002 , H3K4me1_pre_tTreg_TnG5002 , H3K4me1_Treg_TnG5002 , H3K4me1_tTreg_TnG5002 , H3K4me3_pre_tTreg_TnG5002 , H3K4me3_Treg_TnG5002 , H3K4me3_tTreg_TnG5002 , MBD_pre_tTreg_TnG5002 , MBD_Treg_TnG5002 , MBD_tTreg_TnG5002 , Fp3_act_TnG5002 , Fp3_res_TnG5002 , Kik_act_TnG5002 , Kik_res_TnG5002], axis=1)
nonTnG_peak=pd.concat([ATAC_pre_tTreg_nonTnG500 , ATAC_Treg_nonTnG500 , ATAC_tTreg_nonTnG500 , Chips_nonTnG500 , Cutruns_nonTnG500 , Foxp3_Chipseq_Treg_nonTnG500 , H3K27ac_Cd4CreSatb1CKO_pre_tTreg_nonTnG500 , H3K27ac_pre_tTreg_nonTnG500 , H3K27ac_Treg_nonTnG500 , H3K27ac_tTreg_nonTnG500 , H3K27me3_pre_tTreg_nonTnG500 , H3K27me3_Treg_nonTnG500 , H3K27me3_tTreg_nonTnG500 , H3K4me1_pre_tTreg_nonTnG500 , H3K4me1_Treg_nonTnG500 , H3K4me1_tTreg_nonTnG500 , H3K4me3_pre_tTreg_nonTnG500 , H3K4me3_Treg_nonTnG500 , H3K4me3_tTreg_nonTnG500 , MBD_pre_tTreg_nonTnG500 , MBD_Treg_nonTnG500 , MBD_tTreg_nonTnG500 , Fp3_act_nonTnG500 , Fp3_res_nonTnG500 , Kik_act_nonTnG500 , Kik_res_nonTnG500, FPD_nonTnG500, SMC1a_nonTnG500,  SMC1a_nonTnG500_refined], axis=1)
#nonTnG_peak2=pd.concat([ATAC_pre_tTreg_nonTnG5002 , ATAC_Treg_nonTnG5002 , ATAC_tTreg_nonTnG5002 , Chips_nonTnG5002 , Cutruns_nonTnG5002 , Foxp3_Chipseq_Treg_nonTnG5002 , H3K27ac_Cd4CreSatb1CKO_pre_tTreg_nonTnG5002 , H3K27ac_pre_tTreg_nonTnG5002 , H3K27ac_Treg_nonTnG5002 , H3K27ac_tTreg_nonTnG5002 , H3K27me3_pre_tTreg_nonTnG5002 , H3K27me3_Treg_nonTnG5002 , H3K27me3_tTreg_nonTnG5002 , H3K4me1_pre_tTreg_nonTnG5002 , H3K4me1_Treg_nonTnG5002 , H3K4me1_tTreg_nonTnG5002 , H3K4me3_pre_tTreg_nonTnG5002 , H3K4me3_Treg_nonTnG5002 , H3K4me3_tTreg_nonTnG5002 , MBD_pre_tTreg_nonTnG5002 , MBD_Treg_nonTnG5002 , MBD_tTreg_nonTnG5002 , Fp3_act_nonTnG5002 , Fp3_res_nonTnG5002 , Kik_act_nonTnG5002 , Kik_res_nonTnG5002], axis=1)

# %%
TnG_peak.to_csv("TnG_peak_500.csv")
#TnG_peak2.to_csv("TnG_peak2_means.csv")
nonTnG_peak.to_csv("nonTnG_peak_500.csv")
#nonTnG_peak2.to_csv("nonTnG_peak2_means.csv")
